# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn import tree

# %%
data = load_breast_cancer()
X = data.data
y = data.target

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.3,
    random_state=42
)

# %%
clf = DecisionTreeClassifier(
    random_state=42
)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = clf.predict(X_test)

# %%
accuracy = accuracy_score(
    y_test,
    y_pred
)

# %%
print(f"Model accuracy: {accuracy*100:.2f}%")
# Out:
# Model accuracy: 94.15%

# %%
new_sample = np.array([
    X_test[0]
])

# %%
prediction = clf.predict(
    new_sample
)

# %%
prediction_class = (
    "Benign"
    if prediction == 1
    else "Malignant"
)

# %%
print(f"Predicted class for the new sample: {prediction_class}")
# Out:
# Predicted class for the new sample: Benign

# %%
plt.figure(
    figsize=(12,8)
)
tree.plot_tree(
    clf,
    filled=True,
    feature_names=data.feature_names,
    class_names=data.target_names
)
# Out:
# [Text(0.625, 0.9375, 'mean concave points <= 0.051\ngini = 0.468\nsamples = 398\nvalue = [149, 249]\nclass = benign'),
#  Text(0.4318181818181818, 0.8125, 'worst radius <= 16.83\ngini = 0.1\nsamples = 245\nvalue = [13, 232]\nclass = benign'),
#  Text(0.5284090909090909, 0.875, 'True  '),
#  Text(0.3181818181818182, 0.6875, 'area error <= 48.7\ngini = 0.043\nsamples = 230\nvalue = [5, 225]\nclass = benign'),
#  Text(0.22727272727272727, 0.5625, 'worst smoothness <= 0.178\ngini = 0.026\nsamples = 227\nvalue = [3, 224]\nclass = benign'),
#  Text(0.18181818181818182, 0.4375, 'smoothness error <= 0.003\ngini = 0.018\nsamples = 226\nvalue = [2, 224]\nclass = benign'),
#  Text(0.09090909090909091, 0.3125, 'worst texture <= 26.89\ngini = 0.32\nsamples = 5\nvalue = [1, 4]\nclass = benign'),
#  Text(0.045454545454545456, 0.1875, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]\nclass = benign'),
#  Text(0.13636363636363635, 0.1875, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.2727272727272727, 0.3125, 'worst texture <= 33.35\ngini = 0.009\nsamples = 221\nvalue = [1, 220]\nclass = benign'),
#  Text(0.22727272727272727, 0.1875, 'gini = 0.0\nsamples = 208\nvalue = [0, 208]\nclass = benign'),
#  Text(0.3181818181818182, 0.1875, 'worst texture <= 34.5\ngini = 0.142\nsamples = 13\nvalue = [1, 12]\nclass = benign'),
#  Text(0.2727272727272727, 0.0625, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.36363636363636365, 0.0625, 'gini = 0.0\nsamples = 12\nvalue = [0, 12]\nclass = benign'),
#  Text(0.2727272727272727, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]\nclass = malignant'),
#  Text(0.4090909090909091, 0.5625, 'concavity error <= 0.02\ngini = 0.444\nsamples = 3\nvalue = [2, 1]\nclass = malignant'),
#  Text(0.36363636363636365, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]\nclass = malignant'),
#  Text(0.45454545454545453, 0.4375, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]\nclass = benign'),
#  Text(0.5454545454545454, 0.6875, 'mean texture <= 16.19\ngini = 0.498\nsamples = 15\nvalue = [8, 7]\nclass = malignant'),
#  Text(0.5, 0.5625, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]\nclass = benign'),
#  Text(0.5909090909090909, 0.5625, 'concave points error <= 0.01\ngini = 0.32\nsamples = 10\nvalue = [8, 2]\nclass = malignant'),
#  Text(0.5454545454545454, 0.4375, 'gini = 0.0\nsamples = 8\nvalue = [8, 0]\nclass = malignant'),
#  Text(0.6363636363636364, 0.4375, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = benign'),
#  Text(0.8181818181818182, 0.8125, 'worst texture <= 20.405\ngini = 0.198\nsamples = 153\nvalue = [136, 17]\nclass = malignant'),
#  Text(0.7215909090909092, 0.875, '  False'),
#  Text(0.7272727272727273, 0.6875, 'worst radius <= 18.145\ngini = 0.408\nsamples = 14\nvalue = [4, 10]\nclass = benign'),
#  Text(0.6818181818181818, 0.5625, 'gini = 0.0\nsamples = 10\nvalue = [0, 10]\nclass = benign'),
#  Text(0.7727272727272727, 0.5625, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = malignant'),
#  Text(0.9090909090909091, 0.6875, 'worst area <= 718.65\ngini = 0.096\nsamples = 139\nvalue = [132, 7]\nclass = malignant'),
#  Text(0.8636363636363636, 0.5625, 'worst texture <= 25.925\ngini = 0.497\nsamples = 13\nvalue = [6, 7]\nclass = benign'),
#  Text(0.8181818181818182, 0.4375, 'gini = 0.0\nsamples = 7\nvalue = [0, 7]\nclass = benign'),
#  Text(0.9090909090909091, 0.4375, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]\nclass = malignant'),
#  Text(0.9545454545454546, 0.5625, 'gini = 0.0\nsamples = 126\nvalue = [126, 0]\nclass = malignant')]
